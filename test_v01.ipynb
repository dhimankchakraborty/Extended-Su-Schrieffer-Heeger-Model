# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from functions import *

# %%
v = 0.1
w = 1
p = 1
q = 3
steps = 10000


print(np.round(winding_number(v, w, p, q, steps=steps), 3))

k_arr = np.linspace(0, 2 * np.pi, steps)

plt.plot(d_x(k_arr, v, w, p, q), d_y(k_arr, w, p, q))
plt.scatter(0, 0, color='k')
plt.show()
# Out:
# 2.0
